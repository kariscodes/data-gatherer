# %% [markdown]
# ### 데이터 값과 기업정보 최종 결과
# * 결산년도 2017년 ~ 2021년
# * 상장법인(유가증권+코스닥)

# %% [markdown]
# * 데이터 값 목록 가져오기

# %%
import pandas as pd

# 데이터값 파일
file_path = "D:/PythonProject/data-gatherer/dart_fs_notes/items/items_all.csv"
df_items_all = pd.read_csv(file_path, dtype=object)

# 기업개황정보 파일 읽기
file_path = "D:/PythonProject/data-gatherer/dart_fs_notes/company/corp_info_all.csv"
df_corp_info_all = pd.read_csv(file_path, dtype=object)

# %%
df_items_all.head(3)
# Out:
#   corp_code stock_code corp_cls corp_name         rpt_num         rpt_name  \
# 0  00126380     005930        Y      삼성전자  20130401003031  사업보고서 (2012.12)
# 1  00126380     005930        Y      삼성전자  20220308000798  사업보고서 (2021.12)
# 2  00126380     005930        Y      삼성전자  20210309000744  사업보고서 (2020.12)
#
#     doc_title                    doc_result       val_a       val_b  \
# 0         NaN  No Financial Statement Notes         NaN         NaN
# 1  5. 재무제표 주석                            OK  11173636.0  13497927.0
# 2  5. 재무제표 주석                            OK   9754082.0  10916538.0
#
#   item_result
# 0         NaN
# 1          OK
# 2          OK

# %%
df_corp_info_all.head(1)
# Out:
#   status message corp_code   corp_name    corp_name_eng stock_name stock_code  \
# 0    000      정상  00907484  동양플랜트건설(주)  Tong Yang Magic    동양플랜트건설        NaN
#
#   ceo_nm corp_cls       jurir_no bizr_no                         adres hm_url  \
# 0    박종복        E  1101114710441     NaN  서울특별시 영등포구 국제금융로2길 24 (여의도동)    NaN
#
#   ir_url        phn_no        fax_no induty_code    est_dt acc_mt
# 0    NaN  02-6150-7000  02-6150-7159       29173  20111019     12

# %% [markdown]
# * 데이터값과 기업개황정보 결합

# %%
df_result = pd.merge(df_items_all, df_corp_info_all[['corp_code', 'jurir_no', 'bizr_no']], 
                     how='left', left_on='corp_code', right_on='corp_code')

# %%
corp_codes = df_result['corp_code'].unique()

# %%
corp_codes
# Out:
# array(['00126380', '00267960', '00688996'], dtype=object)

# %%
df_result.sort_values(by=['corp_code', 'corp_name'])
# Out:
#    corp_code stock_code corp_cls corp_name         rpt_num  \
# 0   00126380     005930        Y      삼성전자  20130401003031
# 1   00126380     005930        Y      삼성전자  20220308000798
# 2   00126380     005930        Y      삼성전자  20210309000744
# 3   00126380     005930        Y      삼성전자  20200330003851
# 4   00126380     005930        Y      삼성전자  20190401004781
# 5   00126380     005930        Y      삼성전자  20230307000542
# 6   00126380     005930        Y      삼성전자  20170331004518
# 7   00126380     005930        Y      삼성전자  20160330003536
# 8   00126380     005930        Y      삼성전자  20150331002915
# 9   00126380     005930        Y      삼성전자  20140331002427
# 10  00126380     005930        Y      삼성전자  20180402005019
# 11  00267960     036500        E    에스에스컴텍  20130401001954
# 12  00267960     036500        E    에스에스컴텍  20140509000926
# 13  00688996     105560        Y      KB금융  20220325001281
# 14  00688996     105560        Y      KB금융  20130329001808
# ...

# %%
# 정렬
# df_result = df_result.sort_values(by=['rpt_num'], ascending=True)
df_result = df_result.sort_values(by=['corp_code'], ascending=False)
df_result
# Out:
#    corp_code stock_code corp_cls corp_name         rpt_num  \
# 23  00688996     105560        Y      KB금융  20231005000471
# 13  00688996     105560        Y      KB금융  20220325001281
# 22  00688996     105560        Y      KB금융  20210427000354
# 21  00688996     105560        Y      KB금융  20210427000426
# 20  00688996     105560        Y      KB금융  20210427000468
# 19  00688996     105560        Y      KB금융  20210427000533
# 18  00688996     105560        Y      KB금융  20170331004054
# 17  00688996     105560        Y      KB금융  20160401000506
# 16  00688996     105560        Y      KB금융  20150522000391
# 15  00688996     105560        Y      KB금융  20140331002917
# 14  00688996     105560        Y      KB금융  20130329001808
# 12  00267960     036500        E    에스에스컴텍  20140509000926
# 11  00267960     036500        E    에스에스컴텍  20130401001954
# 1   00126380     005930        Y      삼성전자  20220308000798
# 10  00126380     005930        Y      삼성전자  20180402005019
# ...
