# %% [markdown]
# ### 2014년 12월 결산법인 회사들을 대상으로 프로그램 테스트

# %%
import pandas as pd
import traceback
import OpenDartReader
api_key = 'f2e08d4ed3de0ba3d5cbf59c04c223e02b1751a2'
dart = OpenDartReader(api_key)

# %%
def str2num(x):
    if "," in x:
        x = x.replace(",","")
    if x.startswith("(") and x.endswith(")"):
        x = x.lstrip("(")
        x = x.rstrip(")")
        float_num = float(x) * (-1)
    else:
        x = x.lstrip("(")
        x = x.rstrip(")")     
        float_num = float(x)
    return float_num

# %%
reports = dart.list(start='2021-04-01', end='2021-04-01', kind='A', final=True)

# %%
reports
# Out:
#    corp_code             corp_name stock_code corp_cls              report_nm  \
# 0   00242712                   엘컴텍     037950        K  [기재정정]사업보고서 (2020.12)
# 1   00618401                  크루셜텍     114120        K  [기재정정]사업보고서 (2020.12)
# 2   00148896                OCI홀딩스     010060        Y  [기재정정]사업보고서 (2020.12)
# 3   00609315                   멜파스     096640        E  [기재정정]사업보고서 (2020.12)
# 4   00369107                 우리바이오     082850        K  [기재정정]사업보고서 (2020.12)
# 5   00144021                  원풍물산     008290        K  [기재정정]사업보고서 (2020.12)
# 6   00601641                    리드     197210        E        사업보고서 (2020.12)
# 7   01329957                  국전약품     307750        K  [기재정정]사업보고서 (2020.12)
# 8   01134395  뉴스테이허브제1호위탁관리부동산투자회사                   E  [기재정정]사업보고서 (2020.12)
# 9   00288343                 삼영이엔씨     065570        K  [기재정정]사업보고서 (2020.12)
# 10  01267550                 나라소프트     288490        N  [기재정정]사업보고서 (2020.12)
# 11  01390344               HD현대중공업     329180        Y        사업보고서 (2020.12)
# 12  00104537                 국영지앤엠     006050        K  [기재정정]사업보고서 (2020.12)
# 13  00277107             한림오스람임플란트                   E   소액공모법인결산서류 (2020.12)
# 14  00366793                에스제이케이     080440        E  [기재정정]사업보고서 (2020.12)
# 15  00606664                케이엔더블유     105330        K  [기재정정]사업보고서 (2020.12)
# 16  00689418                   지유온     111820        E  [기재정정]분기보고서 (2020.09)
# 17  00917861                슈피겐코리아     192440        K  [기재정정]사업보고서 (2020.12)
# 18  00319041                   엠허브                   E   소액공모법인결산서류 (2020.12)
# 19  01183407                이십일스토어     270020        E        사업보고서 (2020.12)
# 20  01179592                큐젠바이오텍                   E        사업보고서 (2020.12)
#
#           rcept_no                flr_nm  rcept_dt rm
# 0   20210401003209                   엘컴텍  20210401  연
# 1   20210401003051                  크루셜텍  20210401  연
# 2   20210401002874                OCI홀딩스  20210401  연
# 3   20210401002671                   멜파스  20210401  연
# 4   20210401002487                 우리바이오  20210401  연
# 5   20210401002604                  원풍물산  20210401
# 6   20210401002353                    리드  20210401  연
# 7   20210401002323                  국전약품  20210401
# 8   20210401002279  뉴스테이허브제1호위탁관리부동산투자회사  20210401
# 9   20210401002242                 삼영이엔씨  20210401
# 10  20210401001535                 나라소프트  20210401
# 11  20210401001108               HD현대중공업  20210401  연
# 12  20210401001088                 국영지앤엠  20210401
# 13  20210401000896             한림오스람임플란트  20210401
# 14  20210401000889                에스제이케이  20210401  연
# 15  20210401000742                케이엔더블유  20210401  연
# 16  20210401000667                   지유온  20210401
# 17  20210401000621                슈피겐코리아  20210401  연
# 18  20210401000449                   엠허브  20210401
# 19  20210401000216                이십일스토어  20210401  연
# 20  20210401000110                큐젠바이오텍  20210401

# %%
subreports = []
str_expr = "title.str.contains('5. 재무제표 주석')"
for i, row in reports.iterrows():
    try:
        rpt_name = row['report_nm']
        if rpt_name.__contains__('사업보고서'):
            rpt_num = row['rcept_no']        
            rpt_url = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + rpt_num
            df_rpt = dart.sub_docs(rpt_num)
            rpt_data = df_rpt.query(str_expr)       # data frame
            if rpt_data.size != 0:            
                rpt_title = rpt_data.iloc[0]['title']
                rpt_notes_url = rpt_data.iloc[0]['url']
                subreports.append({'rpt_num' : rpt_num, 'corp_name' : row['corp_name'], 'stock_code' : row['stock_code'], 'rpt_name' : rpt_name, 'rpt_url' : rpt_url,
                                'rpt_title' : rpt_title, 'rpt_notes_url' : rpt_notes_url}) 
    except Exception as e:
        print(row['rcept_no'])
        print(row['stock_code'])
        print(row['report_nm'])
        print('http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + row['rcept_no'])
        err_msg = traceback.format_exc()
        print(err_msg)

# %%
subreports
# Out:
# [{'rpt_num': '20210401003209',
#   'corp_name': '엘컴텍',
#   'stock_code': '037950',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401003209',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401003209&dcmNo=7953929&eleId=19&offset=729686&length=334828&dtd=dart3.xsd'},
#  {'rpt_num': '20210401003051',
#   'corp_name': '크루셜텍',
#   'stock_code': '114120',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401003051',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401003051&dcmNo=7952903&eleId=19&offset=1002390&length=350655&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002874',
#   'corp_name': 'OCI홀딩스',
#   'stock_code': '010060',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002874',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002874&dcmNo=7952875&eleId=19&offset=1229304&length=492495&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002671',
#   'corp_name': '멜파스',
#   'stock_code': '096640',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002671',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002671&dcmNo=7952055&eleId=19&offset=851895&length=428066&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002487',
#   'corp_name': '우리바이오',
#   'stock_code': '082850',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002487',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002487&dcmNo=7952052&eleId=19&offset=1064399&length=391675&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002604',
#   'corp_name': '원풍물산',
#   'stock_code': '008290',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002604',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002604&dcmNo=7952046&eleId=19&offset=417126&length=416433&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002353',
#   'corp_name': '리드',
#   'stock_code': '197210',
#   'rpt_name': '사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002353',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002353&dcmNo=7951353&eleId=17&offset=636708&length=287778&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002323',
#   'corp_name': '국전약품',
#   'stock_code': '307750',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002323',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002323&dcmNo=7951271&eleId=19&offset=378854&length=303896&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002279',
#   'corp_name': '뉴스테이허브제1호위탁관리부동산투자회사',
#   'stock_code': '',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002279',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002279&dcmNo=7951145&eleId=19&offset=156321&length=69549&dtd=dart3.xsd'},
#  {'rpt_num': '20210401002242',
#   'corp_name': '삼영이엔씨',
#   'stock_code': '065570',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401002242',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401002242&dcmNo=7950856&eleId=19&offset=446005&length=296186&dtd=dart3.xsd'},
#  {'rpt_num': '20210401001535',
#   'corp_name': '나라소프트',
#   'stock_code': '288490',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401001535',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401001535&dcmNo=7947920&eleId=19&offset=329171&length=260204&dtd=dart3.xsd'},
#  {'rpt_num': '20210401001108',
#   'corp_name': 'HD현대중공업',
#   'stock_code': '329180',
#   'rpt_name': '사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401001108',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401001108&dcmNo=7947716&eleId=17&offset=1012807&length=548228&dtd=dart3.xsd'},
#  {'rpt_num': '20210401001088',
#   'corp_name': '국영지앤엠',
#   'stock_code': '006050',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401001088',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401001088&dcmNo=7947712&eleId=19&offset=206895&length=278957&dtd=dart3.xsd'},
#  {'rpt_num': '20210401000889',
#   'corp_name': '에스제이케이',
#   'stock_code': '080440',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401000889',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401000889&dcmNo=7947149&eleId=19&offset=1052668&length=437961&dtd=dart3.xsd'},
#  {'rpt_num': '20210401000742',
#   'corp_name': '케이엔더블유',
#   'stock_code': '105330',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401000742',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401000742&dcmNo=7946668&eleId=19&offset=673470&length=255052&dtd=dart3.xsd'},
#  {'rpt_num': '20210401000621',
#   'corp_name': '슈피겐코리아',
#   'stock_code': '192440',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401000621',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401000621&dcmNo=7944820&eleId=19&offset=819502&length=386711&dtd=dart3.xsd'},
#  {'rpt_num': '20210401000216',
#   'corp_name': '이십일스토어',
#   'stock_code': '270020',
#   'rpt_name': '사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401000216',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401000216&dcmNo=7945242&eleId=17&offset=835744&length=285888&dtd=dart3.xsd'},
#  {'rpt_num': '20210401000110',
#   'corp_name': '큐젠바이오텍',
#   'stock_code': '',
#   'rpt_name': '사업보고서 (2020.12)',
#   'rpt_url': 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210401000110',
#   'rpt_title': '5. 재무제표 주석',
#   'rpt_notes_url': 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20210401000110&dcmNo=7944808&eleId=17&offset=192200&length=97759&dtd=dart3.xsd'}]

# %%
data_list = []
for r in subreports:
    try:
        url = r['rpt_notes_url']
        doc_data = pd.read_html(url)
        val_a = val_b = None
        for df in doc_data:
            row = df.shape[0]
            for i in range(0, row):
                item = str(df.iloc[i,0])
                if item.__contains__('확정급여채무의 현재가치'):
                    # print(i, type(df.iloc[i,1]), df.iloc[i,1])
                    val_a = str2num(str(df.iloc[i,1]))
                elif item.__contains__('사외적립자산의 공정가치'):
                    # print(i, type(df.iloc[i,1]), df.iloc[i,1])                            
                    val_b = str2num(str(df.iloc[i,1]))
                else:
                    continue              
        data_list.append({'corp_name' : r['corp_name'], 'stock_code' : r['stock_code'], 'rpt_num' : r['rpt_num'], 'rpt_name' : r['rpt_name'], 
                        'val_a' : val_a, 'val_b' : val_b})
    except Exception as e:
        print(r['rpt_num'])
        print(r['rpt_url'])
        print(r['rpt_notes_url'])
        err_msg = traceback.format_exc()
        print(err_msg)

# %%
data_list
# Out:
# [{'corp_name': '엘컴텍',
#   'stock_code': '037950',
#   'rpt_num': '20210401003209',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': 1447783.0,
#   'val_b': -1123856.0},
#  {'corp_name': '크루셜텍',
#   'stock_code': '114120',
#   'rpt_num': '20210401003051',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': 'OCI홀딩스',
#   'stock_code': '010060',
#   'rpt_num': '20210401002874',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': 150685632.0,
#   'val_b': -136848167.0},
#  {'corp_name': '멜파스',
#   'stock_code': '096640',
#   'rpt_num': '20210401002671',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '우리바이오',
#   'stock_code': '082850',
#   'rpt_num': '20210401002487',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': 1968394339.0,
#   'val_b': -1577461428.0},
#  {'corp_name': '원풍물산',
#   'stock_code': '008290',
#   'rpt_num': '20210401002604',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '리드',
#   'stock_code': '197210',
#   'rpt_num': '20210401002353',
#   'rpt_name': '사업보고서 (2020.12)',
#   'val_a': 126130.0,
#   'val_b': -42274.0},
#  {'corp_name': '국전약품',
#   'stock_code': '307750',
#   'rpt_num': '20210401002323',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '뉴스테이허브제1호위탁관리부동산투자회사',
#   'stock_code': '',
#   'rpt_num': '20210401002279',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '삼영이엔씨',
#   'stock_code': '065570',
#   'rpt_num': '20210401002242',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '나라소프트',
#   'stock_code': '288490',
#   'rpt_num': '20210401001535',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': 'HD현대중공업',
#   'stock_code': '329180',
#   'rpt_num': '20210401001108',
#   'rpt_name': '사업보고서 (2020.12)',
#   'val_a': 693107.0,
#   'val_b': -693107.0},
#  {'corp_name': '국영지앤엠',
#   'stock_code': '006050',
#   'rpt_num': '20210401001088',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '에스제이케이',
#   'stock_code': '080440',
#   'rpt_num': '20210401000889',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '케이엔더블유',
#   'stock_code': '105330',
#   'rpt_num': '20210401000742',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '슈피겐코리아',
#   'stock_code': '192440',
#   'rpt_num': '20210401000621',
#   'rpt_name': '[기재정정]사업보고서 (2020.12)',
#   'val_a': 2920180.0,
#   'val_b': None},
#  {'corp_name': '이십일스토어',
#   'stock_code': '270020',
#   'rpt_num': '20210401000216',
#   'rpt_name': '사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None},
#  {'corp_name': '큐젠바이오텍',
#   'stock_code': '',
#   'rpt_num': '20210401000110',
#   'rpt_name': '사업보고서 (2020.12)',
#   'val_a': None,
#   'val_b': None}]

# %%
df_all = pd.DataFrame(data_list)

# %%
df_all
# Out:
#                corp_name stock_code         rpt_num               rpt_name  \
# 0                    엘컴텍     037950  20210401003209  [기재정정]사업보고서 (2020.12)
# 1                   크루셜텍     114120  20210401003051  [기재정정]사업보고서 (2020.12)
# 2                 OCI홀딩스     010060  20210401002874  [기재정정]사업보고서 (2020.12)
# 3                    멜파스     096640  20210401002671  [기재정정]사업보고서 (2020.12)
# 4                  우리바이오     082850  20210401002487  [기재정정]사업보고서 (2020.12)
# 5                   원풍물산     008290  20210401002604  [기재정정]사업보고서 (2020.12)
# 6                     리드     197210  20210401002353        사업보고서 (2020.12)
# 7                   국전약품     307750  20210401002323  [기재정정]사업보고서 (2020.12)
# 8   뉴스테이허브제1호위탁관리부동산투자회사             20210401002279  [기재정정]사업보고서 (2020.12)
# 9                  삼영이엔씨     065570  20210401002242  [기재정정]사업보고서 (2020.12)
# 10                 나라소프트     288490  20210401001535  [기재정정]사업보고서 (2020.12)
# 11               HD현대중공업     329180  20210401001108        사업보고서 (2020.12)
# 12                 국영지앤엠     006050  20210401001088  [기재정정]사업보고서 (2020.12)
# 13                에스제이케이     080440  20210401000889  [기재정정]사업보고서 (2020.12)
# 14                케이엔더블유     105330  20210401000742  [기재정정]사업보고서 (2020.12)
# 15                슈피겐코리아     192440  20210401000621  [기재정정]사업보고서 (2020.12)
# 16                이십일스토어     270020  20210401000216        사업보고서 (2020.12)
# 17                큐젠바이오텍             20210401000110        사업보고서 (2020.12)
#
#            val_a         val_b
# 0   1.447783e+06 -1.123856e+06
# 1            NaN           NaN
# 2   1.506856e+08 -1.368482e+08
# 3            NaN           NaN
# 4   1.968394e+09 -1.577461e+09
# 5            NaN           NaN
# 6   1.261300e+05 -4.227400e+04
# 7            NaN           NaN
# 8            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
# 11  6.931070e+05 -6.931070e+05
# 12           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
# 15  2.920180e+06           NaN
# 16           NaN           NaN
# 17           NaN           NaN

# %%
df_all.dtypes
# Out:
# corp_name      object
# stock_code     object
# rpt_num        object
# rpt_name       object
# val_a         float64
# val_b         float64
# dtype: object

# %%
# df_all.to_excel('D:/PythonProject/data-gatherer/dart/output/result_1d.xlsx')
df_all.to_csv('D:/PythonProject/data-gatherer/dart/output/result_1d.csv')
