# %% [markdown]
# ### 데이터 값 목록 전체

# %% [markdown]
# * 데이터 값 전체 자료를 csv 파일로 저장

# %%
import os
import pandas as pd

# 파일 저장 위치
path_dir = "D:/PythonProject/data-gatherer/dart_fs_notes/items/"
file_list = os.listdir(path_dir)

df_all = pd.DataFrame()    
for file_name in file_list:
    if file_name != 'items_all.csv' and not file_name.startswith('__'):
        df = pd.read_csv(path_dir + file_name, dtype=object)
        df_all = pd.concat([df_all, df])
    
df_all.drop_duplicates(subset=['corp_code','rpt_num'], keep='first', inplace=True, ignore_index=True)            
df_all.to_csv(path_dir + 'items_all.csv', index=False)

# %% [markdown]
# ### 파일에 저장된 데이터 값 목록 검색

# %%
import pandas as pd
# 데이터 Loading
path_dir = "D:/PythonProject/data-gatherer/dart_fs_notes/items/"
df = pd.read_csv(path_dir + 'items_all.csv', dtype=object)
print(df.shape[0])
df.head(3)
# Out:
# 297
#   corp_code stock_code corp_cls corp_name         rpt_num  \
# 0  00101220     001390        Y     KG케미칼  20130604000167
# 1  00101220     001390        Y     KG케미칼  20230321001469
# 2  00101220     001390        Y     KG케미칼  20220321001518
#
#                 rpt_name   doc_title                    doc_result unit  \
# 0  [기재정정]사업보고서 (2012.12)         NaN  No Financial Statement Notes  NaN
# 1        사업보고서 (2022.12)  5. 재무제표 주석                            OK   천원
# 2        사업보고서 (2021.12)  5. 재무제표 주석                            OK   천원
#
#         val_a       val_b item_result
# 0         NaN         NaN         NaN
# 1  10877878.0  11773083.0          OK
# 2  11695697.0  11017382.0          OK

# %%
df['doc_result'].value_counts()
# Out:
# doc_result
# OK                              267
# No Financial Statement Notes     30
# Name: count, dtype: int64

# %%
df['unit'].value_counts()
# Out:
# unit
# 천원     202
# 백만원     56
# 원        9
# Name: count, dtype: int64

# %%
# 오류 찾기: 재무제표 주석 문서가 있으면서 금액 단위가 없는 것
df.query("doc_result == 'OK' and unit.isna()")
# Out:
# Empty DataFrame
# Columns: [corp_code, stock_code, corp_cls, corp_name, rpt_num, rpt_name, doc_title, doc_result, unit, val_a, val_b, item_result]
# Index: []

# %%
df[df["doc_result"] == 'No Financial Statement Notes']
# Out:
#     corp_code stock_code corp_cls corp_name         rpt_num  \
# 0    00101220     001390        Y     KG케미칼  20130604000167
# 9    00101220     001390        Y     KG케미칼  20140331001226
# 10   00101220     001390        Y     KG케미칼  20130604000093
# 20   00107613     007660        Y    이수페타시스  20140530000995
# 21   00107613     007660        Y    이수페타시스  20130401002027
# 49   00113410     000120        Y    CJ대한통운  20140515001391
# 50   00113410     000120        Y    CJ대한통운  20130329001765
# 89   00126201     006660        Y      삼성공조  20140331000739
# 90   00126201     006660        Y      삼성공조  20130401000306
# 100  00126380     005930        Y      삼성전자  20140331002427
# 101  00126380     005930        Y      삼성전자  20130401003031
# 111  00126478     010140        Y     삼성중공업  20140331003348
# 112  00126478     010140        Y     삼성중공업  20130401002778
# 115  00127802     004380        Y     삼익THK  20130509001803
# 116  00127802     004380        Y     삼익THK  20140328000513
# 125  00140177     007070        Y     GS리테일  20140331002932
# 126  00140177     007070        Y     GS리테일  20130401002528
# 163  00165343     003010        Y        혜인  20140331003426
# 164  00165343     003010        Y        혜인  20130401002652
# 166  00267960     036500        E    에스에스컴텍  20130401001954
# 167  00267960     036500        E    에스에스컴텍  20140509000926
# 179  00269940     039130        Y      하나투어  20140331002360
# 180  00269940     039130        Y      하나투어  20130329002563
# 191  00314790        NaN        E  코레이트자산운용  20140630000251
# 192  00314790        NaN        E  코레이트자산운용  20130701000018
# 221  00652423     101140        Y     인바이오젠  20230322000764
# 226  00652423     101140        Y     인바이오젠  20130327000380
# 228  00652423     101140        Y     인바이오젠  20140328000743
# 240  00688996     105560        Y      KB금융  20140331002917
# 241  00688996     105560        Y      KB금융  20130329001808
#
#                      rpt_name doc_title                    doc_result unit  \
# 0       [기재정정]사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 9             사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 10      [기재정정]사업보고서 (2011.12)       NaN  No Financial Statement Notes  NaN
# 20      [기재정정]사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 21            사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 49      [기재정정]사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 50            사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 89            사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 90            사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 100           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 101           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 111           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 112           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 115     [기재정정]사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 116           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 125           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 126           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 163           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 164           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 166           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 167     [기재정정]사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 179     [첨부추가]사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 180           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 191           사업보고서 (2014.03)       NaN  No Financial Statement Notes  NaN
# 192     [첨부정정]사업보고서 (2013.03)       NaN  No Financial Statement Notes  NaN
# 221  사업보고서제출기한연장신고서 (2022.12)       NaN  No Financial Statement Notes  NaN
# 226           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
# 228           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 240           사업보고서 (2013.12)       NaN  No Financial Statement Notes  NaN
# 241           사업보고서 (2012.12)       NaN  No Financial Statement Notes  NaN
#
#     val_a val_b item_result
# 0     NaN   NaN         NaN
# 9     NaN   NaN         NaN
# 10    NaN   NaN         NaN
# 20    NaN   NaN         NaN
# 21    NaN   NaN         NaN
# 49    NaN   NaN         NaN
# 50    NaN   NaN         NaN
# 89    NaN   NaN         NaN
# 90    NaN   NaN         NaN
# 100   NaN   NaN         NaN
# 101   NaN   NaN         NaN
# 111   NaN   NaN         NaN
# 112   NaN   NaN         NaN
# 115   NaN   NaN         NaN
# 116   NaN   NaN         NaN
# 125   NaN   NaN         NaN
# 126   NaN   NaN         NaN
# 163   NaN   NaN         NaN
# 164   NaN   NaN         NaN
# 166   NaN   NaN         NaN
# 167   NaN   NaN         NaN
# 179   NaN   NaN         NaN
# 180   NaN   NaN         NaN
# 191   NaN   NaN         NaN
# 192   NaN   NaN         NaN
# 221   NaN   NaN         NaN
# 226   NaN   NaN         NaN
# 228   NaN   NaN         NaN
# 240   NaN   NaN         NaN
# 241   NaN   NaN         NaN
