# %%
import pandas as pd
import traceback
import OpenDartReader
api_key = 'f2e08d4ed3de0ba3d5cbf59c04c223e02b1751a2'
dart = OpenDartReader(api_key)

# %%
def str2num(x):
    if "," in x:
        x = x.replace(",","")
    if x.startswith("(") and x.endswith(")"):
        x = x.lstrip("(")
        x = x.rstrip(")")
        float_num = float(x) * (-1)
    else:
        x = x.lstrip("(")
        x = x.rstrip(")")     
        float_num = float(x)
    return float_num

# %%
reports = dart.list(start='2021-04-02', end='2021-04-11', kind='A', final=True)

# %%
reports
# Out:
#    corp_code corp_name stock_code corp_cls                   report_nm  \
# 0   01259454      아들과딸                   E             사업보고서 (2020.12)
# 1   00148276      제일기획     030000        Y       [기재정정]사업보고서 (2020.12)
# 2   00623184    휴림네트웍스     192410        K       [기재정정]사업보고서 (2020.12)
# 3   01058101       라파스     214260        K       [기재정정]사업보고서 (2019.12)
# 4   00874937        탑선     180060        N       [기재정정]사업보고서 (2020.12)
# 5   00243979    수성샐바시온     084180        K       [첨부정정]사업보고서 (2020.12)
# 6   00372882      KTcs     058850        Y       [기재정정]사업보고서 (2020.12)
# 7   00260611    웰킵스하이텍     043590        K       [기재정정]사업보고서 (2019.12)
# 8   00783246    글로벌에스엠     900070        K             사업보고서 (2020.12)
# 9   00146719    일화모직공업     001590        E             분기보고서 (2021.02)
# 10  00603278     현대커머셜                   E       [기재정정]사업보고서 (2020.12)
# 11  01207169      엑심베이                   E       [첨부정정]사업보고서 (2020.12)
# 12  00660033     씨엔플러스     115530        K             사업보고서 (2020.12)
# 13  00340111    티맥스소프트                   E             사업보고서 (2020.12)
# 14  00302078    엠피씨플러스     050540        E             사업보고서 (2020.12)
# 15  00609485     웅진에너지     103130        E             사업보고서 (2020.12)
# 16  00406037   CSA 코스믹     083660        K             사업보고서 (2020.12)
# 17  01399992       뉴라텍                   E             사업보고서 (2020.12)
# 18  00244419      디에스티     033430        E       [첨부정정]사업보고서 (2020.12)
# 19  01210048     이앤코리아                   E       [첨부정정]사업보고서 (2020.12)
# 20  00120906   에스아이리소스     065420        K       [기재정정]사업보고서 (2020.12)
# 21  01343072      온페이스                   E             사업보고서 (2020.12)
# 22  01138771  온페이스에스디씨                   E             사업보고서 (2020.12)
# 23  00406329       루멘스     038060        K             사업보고서 (2020.12)
# 24  00226228        한프     066110        E             사업보고서 (2020.12)
# 25  00126089     대유플러스     000300        Y       [기재정정]사업보고서 (2020.12)
# 26  00260611    웰킵스하이텍     043590        K             사업보고서 (2020.12)
# 27  00311270        원텍     216280        E             사업보고서 (2020.12)
# 28  00549925      루트로닉     085370        E       [기재정정]사업보고서 (2019.12)
# 29  00660121  디에이테크놀로지     196490        K       [기재정정]사업보고서 (2020.12)
# 30  01339237  여주에너지서비스                   E       [기재정정]사업보고서 (2020.12)
# 31  00501970      퀀타피아     078940        K       [기재정정]사업보고서 (2020.12)
# 32  00442835      메타랩스     090370        Y       [첨부정정]사업보고서 (2020.12)
# 33  00109693        DL     000210        Y       [기재정정]사업보고서 (2020.12)
# 34  00107613    이수페타시스     007660        Y       [기재정정]사업보고서 (2020.12)
# 35  00103592      광동제약     009290        Y       [기재정정]사업보고서 (2020.12)
# 36  01199259      에이필드                   E  [첨부추가]소액공모법인결산서류 (2020.12)
# 37  01043853     베노티앤알     206400        K       [기재정정]사업보고서 (2020.12)
# 38  00689418       지유온     111820        E       [기재정정]분기보고서 (2020.03)
# 39  00370255       테크엘     064520        K       [기재정정]사업보고서 (2019.12)
# 40  01150311        선우                   E       [기재정정]사업보고서 (2020.12)
# 41  00454399    이상네트웍스     080010        K       [기재정정]사업보고서 (2020.12)
# 42  00491983   대우로지스틱스                   E       [기재정정]사업보고서 (2020.12)
# 43  00110884     엠젠솔루션     032790        K       [기재정정]사업보고서 (2020.12)
# 44  00876209  미래엔에듀파트너     208890        N       [기재정정]사업보고서 (2020.12)
# 45  00261054        EG     037370        K       [기재정정]사업보고서 (2020.12)
# 46  00100601     강원에너지     114190        K             사업보고서 (2020.12)
# 47  01049422      썸에이지     208640        K       [기재정정]사업보고서 (2020.12)
# 48  00689418       지유온     111820        E       [기재정정]반기보고서 (2020.06)
# 49  00261285    한국가스공사     036460        Y       [첨부정정]사업보고서 (2020.12)
# 50  01335985  지플러스생명과학                   E       [첨부정정]사업보고서 (2020.12)
# 51  00238977     에스엠화진     134780        E             사업보고서 (2020.12)
#
#           rcept_no    flr_nm  rcept_dt rm
# 0   20210409003049      아들과딸  20210409  연
# 1   20210409002715      제일기획  20210409  연
# 2   20210409002653    휴림네트웍스  20210409  연
# 3   20210409002282       라파스  20210409  연
# 4   20210409002049        탑선  20210409  연
# 5   20210409001381    수성샐바시온  20210409  연
# 6   20210409000489      KTcs  20210409  연
# 7   20210409000378    웰킵스하이텍  20210409  연
# 8   20210409000239    글로벌에스엠  20210409  연
# 9   20210409000011    일화모직공업  20210409
# 10  20210408002358     현대커머셜  20210408
# 11  20210408001625      엑심베이  20210408  연
# 12  20210408000001     씨엔플러스  20210408  연
# 13  20210407003034    티맥스소프트  20210407
# 14  20210407002964    엠피씨플러스  20210407  연
# 15  20210407002862     웅진에너지  20210407
# 16  20210407002779   CSA 코스믹  20210407  연
# 17  20210407002747       뉴라텍  20210407  연
# 18  20210407002704      디에스티  20210407  연
# 19  20210407002655     이앤코리아  20210407
# 20  20210407002561   에스아이리소스  20210407
# 21  20210407002483      온페이스  20210407  연
# 22  20210407002394  온페이스에스디씨  20210407
# 23  20210407002346       루멘스  20210407  연
# 24  20210407000691        한프  20210407  연
# 25  20210406002956     대유플러스  20210407  연
# 26  20210406002964    웰킵스하이텍  20210407  연
# 27  20210406002764        원텍  20210406  연
# 28  20210406002683      루트로닉  20210406  연
# 29  20210406001324  디에이테크놀로지  20210406  연
# 30  20210406000611  여주에너지서비스  20210406
# 31  20210406000396      퀀타피아  20210406  연
# 32  20210405003124      메타랩스  20210405  연
# 33  20210405003117        DL  20210405  연
# 34  20210405003044    이수페타시스  20210405  연
# 35  20210405002921      광동제약  20210405  연
# 36  20210405002550      에이필드  20210405
# 37  20210405002407     베노티앤알  20210405  연
# 38  20210405002037       지유온  20210405
# 39  20210405001932       테크엘  20210405  연
# 40  20210405001442        선우  20210405
# 41  20210405000538    이상네트웍스  20210405  연
# 42  20210405000085   대우로지스틱스  20210405
# 43  20210402002682     엠젠솔루션  20210402  연
# 44  20210402002327  미래엔에듀파트너  20210402  연
# 45  20210402002208        EG  20210402  연
# 46  20210402002033     강원에너지  20210402  연
# 47  20210402001628      썸에이지  20210402  연
# 48  20210402001605       지유온  20210402
# 49  20210402001462    한국가스공사  20210402  연
# 50  20210402001375  지플러스생명과학  20210402  연
# 51  20210402000001     에스엠화진  20210402  연

# %%
str_expr = "report_nm.str.contains('사업보고서')"
biz_repports = reports.query(str_expr)

# %%
biz_repports.shape
# Out:
# (48, 9)

# %%
subreports = []
str_expr = "title.str.contains('5. 재무제표 주석')"
for i, row in biz_repports.iterrows():
    try:
        rpt_name = row['report_nm']
        rpt_num = row['rcept_no']        
        rpt_url = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + rpt_num
        df_rpt = dart.sub_docs(rpt_num)
        rpt_data = df_rpt.query(str_expr)       # data frame
        if rpt_data.size == 0:
            subreports.append({'rpt_num' : rpt_num, 'corp_name' : row['corp_name'], 'stock_code' : row['stock_code'], 'rpt_name' : rpt_name, 'rpt_url' : rpt_url,
                            'rpt_title' : None, 'rpt_notes_url' : None})                 
        else:
            rpt_title = rpt_data.iloc[0]['title']
            rpt_notes_url = rpt_data.iloc[0]['url']
            subreports.append({'rpt_num' : rpt_num, 'corp_name' : row['corp_name'], 'stock_code' : row['stock_code'], 'rpt_name' : rpt_name, 'rpt_url' : rpt_url,
                            'rpt_title' : rpt_title, 'rpt_notes_url' : rpt_notes_url}) 
    except Exception as e:
        print(row['rcept_no'])
        print(row['stock_code'])
        print(row['report_nm'])
        print('http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + row['rcept_no'])
        err_msg = traceback.format_exc()
        print(err_msg)

# %%
len(subreports)
# Out:
# 48

# %%
data_list = []
for r in subreports:
    try:
        val_a = val_b = None
        url = r['rpt_notes_url']
        if url == None:
            data_list.append({'corp_name' : r['corp_name'], 'stock_code' : r['stock_code'], 'rpt_num' : r['rpt_num'], 'rpt_name' : r['rpt_name'], 
                            'val_a' : None, 'val_b' : None})
        else:
            doc_data = pd.read_html(url)
            for df in doc_data:
                row = df.shape[0]
                for i in range(0, row):
                    item = str(df.iloc[i,0])
                    if item.__contains__('확정급여채무의 현재가치'):
                        # print(i, type(df.iloc[i,1]), df.iloc[i,1])
                        str_a = str(df.iloc[i,1])
                        if str_a == "-": val_a = None
                        else: val_a = str2num(str_a)
                    elif item.__contains__('사외적립자산의 공정가치'):
                        # print(i, type(df.iloc[i,1]), df.iloc[i,1])                            
                        str_b = str(df.iloc[i,1])
                        if str_b == "-": val_b = None
                        else: val_b = str2num(str_b)
                    else:
                        continue    
                if (val_a != None) and (val_b != None):
                    break          
            data_list.append({'corp_name' : r['corp_name'], 'stock_code' : r['stock_code'], 'rpt_num' : r['rpt_num'], 'rpt_name' : r['rpt_name'], 
                            'val_a' : val_a, 'val_b' : val_b})
    except ValueError as err:
        print(r['rpt_num'])
        print(r['rpt_url'])
        print(r['rpt_notes_url'])
        print(err)
        data_list.append({'corp_name' : r['corp_name'], 'stock_code' : r['stock_code'], 'rpt_num' : r['rpt_num'], 'rpt_name' : r['rpt_name'], 
                        'val_a' : val_a, 'val_b' : val_b})        
    except Exception as e:
        print(r['rpt_num'])
        print(r['rpt_url'])
        print(r['rpt_notes_url'])
        err_msg = traceback.format_exc()
        print(err_msg)
# Out:
# 20210409003049
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210409003049
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20210409003049&dcmNo=8005681&eleId=17&offset=400094&length=347&dtd=dart3.xsd
# No tables found
# 20210409000239
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20210409000239
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20210409000239&dcmNo=7997032&eleId=17&offset=817149&length=143&dtd=dart3.xsd
# No tables found

# %%
len(data_list)
# Out:
# 48

# %%
df_all = pd.DataFrame(data_list)

# %%
df_all.shape
# Out:
# (48, 6)

# %%
df_all
# Out:
#    corp_name stock_code         rpt_num               rpt_name         val_a  \
# 0       아들과딸             20210409003049        사업보고서 (2020.12)           NaN
# 1       제일기획     030000  20210409002715  [기재정정]사업보고서 (2020.12)  2.143330e+05
# 2     휴림네트웍스     192410  20210409002653  [기재정정]사업보고서 (2020.12)           NaN
# 3        라파스     214260  20210409002282  [기재정정]사업보고서 (2019.12)           NaN
# 4         탑선     180060  20210409002049  [기재정정]사업보고서 (2020.12)           NaN
# 5     수성샐바시온     084180  20210409001381  [첨부정정]사업보고서 (2020.12)           NaN
# 6       KTcs     058850  20210409000489  [기재정정]사업보고서 (2020.12)  8.178484e+07
# 7     웰킵스하이텍     043590  20210409000378  [기재정정]사업보고서 (2019.12)           NaN
# 8     글로벌에스엠     900070  20210409000239        사업보고서 (2020.12)           NaN
# 9      현대커머셜             20210408002358  [기재정정]사업보고서 (2020.12)  3.540144e+07
# 10      엑심베이             20210408001625  [첨부정정]사업보고서 (2020.12)           NaN
# 11     씨엔플러스     115530  20210408000001        사업보고서 (2020.12)           NaN
# 12    티맥스소프트             20210407003034        사업보고서 (2020.12)           NaN
# 13    엠피씨플러스     050540  20210407002964        사업보고서 (2020.12)  4.548560e+05
# 14     웅진에너지     103130  20210407002862        사업보고서 (2020.12)  9.953660e+05
# 15   CSA 코스믹     083660  20210407002779        사업보고서 (2020.12)           NaN
# 16       뉴라텍             20210407002747        사업보고서 (2020.12)           NaN
# 17      디에스티     033430  20210407002704  [첨부정정]사업보고서 (2020.12)           NaN
# 18     이앤코리아             20210407002655  [첨부정정]사업보고서 (2020.12)           NaN
# 19   에스아이리소스     065420  20210407002561  [기재정정]사업보고서 (2020.12)           NaN
# 20      온페이스             20210407002483        사업보고서 (2020.12)           NaN
# 21  온페이스에스디씨             20210407002394        사업보고서 (2020.12)           NaN
# 22       루멘스     038060  20210407002346        사업보고서 (2020.12)           NaN
# 23        한프     066110  20210407000691        사업보고서 (2020.12)  7.718320e+05
# 24     대유플러스     000300  20210406002956  [기재정정]사업보고서 (2020.12)  4.649876e+06
# 25    웰킵스하이텍     043590  20210406002964        사업보고서 (2020.12)           NaN
# 26        원텍     216280  20210406002764        사업보고서 (2020.12)  2.009420e+05
# 27      루트로닉     085370  20210406002683  [기재정정]사업보고서 (2019.12)  7.285643e+09
# 28  디에이테크놀로지     196490  20210406001324  [기재정정]사업보고서 (2020.12)  3.595270e+06
# 29  여주에너지서비스             20210406000611  [기재정정]사업보고서 (2020.12)  2.151590e+05
# 30      퀀타피아     078940  20210406000396  [기재정정]사업보고서 (2020.12)           NaN
# 31      메타랩스     090370  20210405003124  [첨부정정]사업보고서 (2020.12)           NaN
# 32        DL     000210  20210405003117  [기재정정]사업보고서 (2020.12)  4.306900e+04
# 33    이수페타시스     007660  20210405003044  [기재정정]사업보고서 (2020.12)  8.715485e+07
# 34      광동제약     009290  20210405002921  [기재정정]사업보고서 (2020.12)  1.191568e+07
# 35     베노티앤알     206400  20210405002407  [기재정정]사업보고서 (2020.12)  2.654420e+05
# 36       테크엘     064520  20210405001932  [기재정정]사업보고서 (2019.12)  2.580155e+06
# 37        선우             20210405001442  [기재정정]사업보고서 (2020.12)           NaN
# 38    이상네트웍스     080010  20210405000538  [기재정정]사업보고서 (2020.12)           NaN
# 39   대우로지스틱스             20210405000085  [기재정정]사업보고서 (2020.12)           NaN
# 40     엠젠솔루션     032790  20210402002682  [기재정정]사업보고서 (2020.12)           NaN
# 41  미래엔에듀파트너     208890  20210402002327  [기재정정]사업보고서 (2020.12)           NaN
# 42        EG     037370  20210402002208  [기재정정]사업보고서 (2020.12)           NaN
# 43     강원에너지     114190  20210402002033        사업보고서 (2020.12)           NaN
# 44      썸에이지     208640  20210402001628  [기재정정]사업보고서 (2020.12)  8.275700e+04
# 45    한국가스공사     036460  20210402001462  [첨부정정]사업보고서 (2020.12)           NaN
# 46  지플러스생명과학             20210402001375  [첨부정정]사업보고서 (2020.12)           NaN
# 47     에스엠화진     134780  20210402000001        사업보고서 (2020.12)  5.301659e+06
#
#            val_b
# 0            NaN
# 1  -8.909853e+07
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6  -7.971318e+07
# 7            NaN
# 8            NaN
# 9  -3.691062e+07
# 10           NaN
# 11           NaN
# 12           NaN
# 13 -4.548560e+05
# 14 -6.992640e+05
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23 -5.601600e+04
# 24 -6.007320e+05
# 25           NaN
# 26           NaN
# 27 -5.057952e+09
# 28 -3.168323e+06
# 29 -2.083000e+05
# 30           NaN
# 31           NaN
# 32 -4.047600e+04
# 33 -8.322269e+07
# 34 -1.286156e+07
# 35 -1.999200e+05
# 36 -2.453979e+06
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47 -3.142274e+06

# %%
df_all.dtypes
# Out:
# corp_name      object
# stock_code     object
# rpt_num        object
# rpt_name       object
# val_a         float64
# val_b         float64
# dtype: object

# %%
# df_all.to_excel('D:/PythonProject/data-gatherer/dart/output/result1.xlsx')
df_all.to_csv('D:/PythonProject/data-gatherer/dart/output/result1.csv')
