# %%
key = "YTg2NjFjM2FkOGFjZWQ5ODBmMDY1M2IwZTZiNjRlNzg="
url = "https://kosis.kr/openapi/statisticsSearch.do?method=getList"   # 요청 URL

# %%
search_string = "물가지수"

# %%
import requests
import warnings
warnings.filterwarnings('ignore')

params ={'apiKey' : key,                # 발급된 인증 key
        'searchNm' : search_string,     # 검색명
        'jsonVD' : "Y",
        'orgId' : None,
        'startCount' : '1',
        'resultCount' : '1000',
        'sort' : 'RANK',
        "jsonVD" : "Y",            # 결과 유형이 "json"인 경우 필수        
        'format' : "json"               # 결과 유형
        }

response = requests.get(url, params=params, verify=False)

# %%
import json
import pandas as pd

contents = response.text    
json_data = json.loads(contents)
df = pd.DataFrame(json_data)

# %%
df.shape
# Out:
# (245, 18)

# %%
df
# Out:
#     ORG_ID   ORG_NM          TBL_ID                         TBL_NM  \
# 0      101      통계청      DT_1J22003              소비자물가지수(2020=100)
# 1      101      통계청      DT_1J22001  지출목적별 소비자물가지수(품목포함, 2020=100)
# 2      101      통계청     INH_1J22003                    소비자물가지수(시도)
# 3      101      통계청      DT_1J22112   품목별 소비자물가지수(품목성질별: 2020=100)
# 4      101      통계청      DT_1J22002        품목성질별 소비자물가지수(2020=100)
# ..     ...      ...             ...                            ...
# 220    216     경상북도        DT_30003             소비자 물가지수(2000=100)
# 221    202    부산광역시         DT_808A             주요상품 소비자물가지수(1995)
# 222    218  제주특별자치도    TX_218020366                  주요 품목 소비자물가지수
# 223    212     충청북도          DT_M16                       소비자 물가지수
# 224   999S      통계청  DT_999S_207062                     서울 소비자물가지수
#
#                 STAT_ID  STAT_NM            VW_CD  \
# 0               1964001  소비자물가조사        MT_ZTITLE
# 1               1964001  소비자물가조사        MT_ZTITLE
# 2               1964001  소비자물가조사      MT_GTITLE01
# 3               1964001  소비자물가조사        MT_ZTITLE
# 4               1964001  소비자물가조사        MT_ZTITLE
# ..                  ...      ...              ...
# 220         MT_OTITLE13     시도통계        MT_ZTITLE
# 221         MT_OTITLE11   시도기본통계        MT_ZTITLE
# 222         MT_OTITLE11   시도기본통계        MT_ZTITLE
# 223         MT_OTITLE11   시도기본통계        MT_ZTITLE
# 224  G99920091109002455   한국통계연감  MT_HANKUK_TITLE
#
#                                              MT_ATITLE  \
# 0                                         물가 > 소비자물가조사
# 1                                         물가 > 소비자물가조사
# 2                                         주제별 > 소득과 소비
# 3                                         물가 > 소비자물가조사
# 4                                         물가 > 소비자물가조사
# ..                                                 ...
# 220  지역통계 > 인구 및 사회(사회조사) > 경상북도 > 경상북도사회조사 > 2013년...
# 221  지역통계 > 지자체 기본통계 > 부산광역시 > 부산광역시기본통계 > 유통・금융・보험...
# 222  지역통계 > 지자체 기본통계 > 제주특별자치도 > 제주특별자치도기본통계 > 2010...
# 223  지역통계 > 지자체 기본통계 > 충청북도 > 충청북도기본통계 > 유통・금융・보험 및...
# 224                                         물가・가계 > 물가
#
#                                           FULL_PATH_ID  \
# 0                                            P2 > P2_6
# 1                                            P2 > P2_6
# 2                                                  105
# 3                                            P2 > P2_6
# 4                                            P2 > P2_6
# ..                                                 ...
# 220  V > V_2 > V_2_216 > 216_21605 > 216_21605_100 ...
# 221        V > V_1 > V_1_202 > 202_20203 > 202_20203_H
# 222  V > V_1 > V_1_218 > 218_218002 > 218_21802 > 2...
# 223      V > V_1 > V_1_212 > 212_21202 > 212_21202_008
# 224                                             D > D1
#
#                                               CONTENTS STRT_PRD_DE END_PRD_DE  \
# 0    시도별 소비자물가지수(총지수) 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주...        1965       2024
# 1    시도별 지출목적별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광...        1965       2024
# 2    시도별 소비자물가지수(총지수) 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주...        1965       2024
# 3    시도별 품목별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주광...        1975       2024
# 4    시도별 품목성질별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광...        1985       2024
# ..                                                 ...         ...        ...
# 220  지수별 총지수 식료품 주거비 수도광열 가구가사용품 피복신발 보건의료 교육 교양오락 ...        2000       2005
# 221  소비자물가기본분류별 주요상품 소비자 물가지수 일반미 두부 설탕 밀가루 쇠고기 돼지고...        1995       1995
# 222  주요품목별 주요 품목 소비자물가지수 일반미 재래미(정품중미) 밀가루 중력분1등급 재...        1996       1996
# 223  ... 이외 주거비 집세 주택설비수리 주택설비수리재료 주택설비수리서비스 기타주거 광...        2003       2005
# 224  물가지수별 지수 총지수 평균 대전월비 음식물비 평균 주식물 부식물 기호품 주거비 평...        1955       1961
#
#                                                 ITEM03 REC_TBL_SE  \
# 0    - 2019년 이전 지수는 소수점 이하 3자리, 2020년 이후 지수는 소수점 이하...          N
# 1    - 현재 소비자물가지수의 기준연도는 2020년, 가중치의 기준연도는 2022년입니다...          N
# 2    - 소비자물가지수: 가구에서 일상소비생활을 영위하기 위해 구입하는 상품과 서비스의 ...          N
# 3    - 지역별로 기준시점(2020년)의 가격수준이 다르기 때문에 지역별 소비자물가지수를...          N
# 4    - 2019년 이전 지수는 소수점 이하 3자리, 2020년 이후 지수는 소수점 이하...          N
# ..                                                 ...        ...
# 220                자료:통계청「물가통계연보」; 구매력지수 = 100/소비자물가지수          N
# 221                                           자료 : 통계청          N
# 222                                    (1995=100)지수 적용          N
# 223  자료 : 통계청, 「물가연보」 주 : 기준년도는 2000년, 조사품목은 516개 상...          N
# 224  자료 : 한국은행 조사부 지수 : 1955=100 이 지수가 지금까지 계속되어 오는...          N
#
#                                           TBL_VIEW_URL  \
# 0    https://kosis.kr/statisticsList/statisticsList...
# 1    https://kosis.kr/statisticsList/statisticsList...
# 2    https://kosis.kr/statisticsList/statisticsList...
# 3    https://kosis.kr/statisticsList/statisticsList...
# 4    https://kosis.kr/statisticsList/statisticsList...
# ..                                                 ...
# 220  https://kosis.kr/statisticsList/statisticsList...
# 221  https://kosis.kr/statisticsList/statisticsList...
# 222  https://kosis.kr/statisticsList/statisticsList...
# 223  https://kosis.kr/statisticsList/statisticsList...
# 224  https://kosis.kr/statisticsList/statisticsList...
#
#                                               LINK_URL STAT_DB_CNT    QUERY
# 0    http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 1    http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 2    http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 3    http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 4    http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# ..                                                 ...         ...      ...
# 220  http://kosis.kr/statHtml/statHtml.do?orgId=216...         225  소비자물가지수
# 221  http://kosis.kr/statHtml/statHtml.do?orgId=202...         225  소비자물가지수
# 222  http://kosis.kr/statHtml/statHtml.do?orgId=218...         225  소비자물가지수
# 223  http://kosis.kr/statHtml/statHtml.do?orgId=212...         225  소비자물가지수
# 224  http://kosis.kr/statHtml/statHtml.do?orgId=999...         225  소비자물가지수
#
# [225 rows x 18 columns]

# %%
# 현재까지 데이터가 갱신되고 있는 목록 확인
df[(df['END_PRD_DE'] == '2024') & (df['TBL_NM'].str.contains("물가지수"))]
# Out:
#    ORG_ID ORG_NM       TBL_ID                         TBL_NM  STAT_ID  \
# 0     101    통계청   DT_1J22003              소비자물가지수(2020=100)  1964001
# 1     101    통계청   DT_1J22001  지출목적별 소비자물가지수(품목포함, 2020=100)  1964001
# 2     101    통계청  INH_1J22003                    소비자물가지수(시도)  1964001
# 3     101    통계청   DT_1J22112   품목별 소비자물가지수(품목성질별: 2020=100)  1964001
# 4     101    통계청   DT_1J22002        품목성질별 소비자물가지수(2020=100)  1964001
# 5     101    통계청   DT_1J22006      자가주거비포함 소비자물가지수(2020=100)  1964001
# 11    101    통계청   DT_1J22010         특수분류 소비자물가지수(2020=100)  1964001
# 37    101    통계청   DT_1J22005               생활물가지수(2020=100)  1964001
#
#     STAT_NM        VW_CD     MT_ATITLE FULL_PATH_ID  \
# 0   소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 1   소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 2   소비자물가조사  MT_GTITLE01  주제별 > 소득과 소비          105
# 3   소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 4   소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 5   소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 11  소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
# 37  소비자물가조사    MT_ZTITLE  물가 > 소비자물가조사    P2 > P2_6
#
#                                              CONTENTS STRT_PRD_DE END_PRD_DE  \
# 0   시도별 소비자물가지수(총지수) 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주...        1965       2024
# 1   시도별 지출목적별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광...        1965       2024
# 2   시도별 소비자물가지수(총지수) 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주...        1965       2024
# 3   시도별 품목별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주광...        1975       2024
# 4   시도별 품목성질별 소비자물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광...        1985       2024
# 5          자가주거비용포함 소비자물가지수(2020=100) 자가주거비포함지수 자가주거비        1995       2024
# 11                특수분류 소비자물가지수 총지수 에너지 주거비 주거비 제외 서비스        2015       2024
# 37  시도별 품목별 생활물가지수 전국 서울특별시 부산광역시 대구광역시 인천광역시 광주광역...        1995       2024
#
#                                                ITEM03 REC_TBL_SE  \
# 0   - 2019년 이전 지수는 소수점 이하 3자리, 2020년 이후 지수는 소수점 이하...          N
# 1   - 현재 소비자물가지수의 기준연도는 2020년, 가중치의 기준연도는 2022년입니다...          N
# 2   - 소비자물가지수: 가구에서 일상소비생활을 영위하기 위해 구입하는 상품과 서비스의 ...          N
# 3   - 지역별로 기준시점(2020년)의 가격수준이 다르기 때문에 지역별 소비자물가지수를...          N
# 4   - 2019년 이전 지수는 소수점 이하 3자리, 2020년 이후 지수는 소수점 이하...          N
# 5   - 2019년 이전 지수는 소수점 이하 3자리, 2020년 이후 지수는 소수점 이하...          N
# 11  - 현재 소비자물가지수의 기준연도는 2020년, 가중치의 기준연도는 2022년입니다...          N
# 37  * (당초) 이월 : 미출회기간 중의 지수를 출회기간의 마지막 달의 지수와 동일하게...          N
#
#                                          TBL_VIEW_URL  \
# 0   https://kosis.kr/statisticsList/statisticsList...
# 1   https://kosis.kr/statisticsList/statisticsList...
# 2   https://kosis.kr/statisticsList/statisticsList...
# 3   https://kosis.kr/statisticsList/statisticsList...
# 4   https://kosis.kr/statisticsList/statisticsList...
# 5   https://kosis.kr/statisticsList/statisticsList...
# 11  https://kosis.kr/statisticsList/statisticsList...
# 37  https://kosis.kr/statisticsList/statisticsList...
#
#                                              LINK_URL STAT_DB_CNT    QUERY
# 0   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 1   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 2   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 3   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 4   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 5   http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 11  http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
# 37  http://kosis.kr/statHtml/statHtml.do?orgId=101...         225  소비자물가지수
