# %% [markdown]
# # 한국은행 경제통계시스템 Open API
# + 작성: 임경호
# + 한국은행 경제통계 Open API https://ecos.bok.or.kr/api/#/

# %% [markdown]
# ### 서비스 통계 목록

# %%
import requests
import json
import pandas as pd

api_key = 'T4GS4G5ZJSQI9HOTYV64'

service_name = 'StatisticTableList'        # 서비스 통계 목록
req_type = 'json'
req_start, req_end = '1', '1000'
stat_code = ''                      # 통계표코드. 지정하지 않으면 전체 가져옴

url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/{req_start}/{req_end}'

response = requests.get(url)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")
    
jo = json.loads(response.text)
df_result = pd.json_normalize(jo[service_name]['row'])

# %%
df_result.shape
# Out:
# (820, 6)

# %% [markdown]
# + 결과값
#   - P_STAT_CODE	: 상위통계표코드
#   - STAT_CODE : 통계표코드
#   - STAT_NAME : 통계명
#   - CYCLE : 주기(년, 분기, 월)
#   - SRCH_YN	: 검색가능여부
#   - ORG_NAME : 출처

# %%
df_result.head(3)
# Out:
#   P_STAT_CODE   STAT_CODE    STAT_NAME CYCLE SRCH_YN ORG_NAME
# 0           *  0000000001     1. 통화/금융  None       N     None
# 1  0000000001  0000000002  1.1. 통화/유동성  None       N     None
# 2  0000000002  0000000003  1.1.1. 본원통화  None       N     None

# %%
df_result[df_result.STAT_NAME.str.contains("환율")]
# Out:
#     P_STAT_CODE   STAT_CODE                         STAT_NAME CYCLE SRCH_YN  \
# 431           *  0000000176                 3. 환율/통관수출입/외환보유액  None       N
# 432  0000000176  0000000177                           3.1. 환율  None       N
# 433  0000000177  0000000178                       3.1.1. 일일환율  None       N
# 434  0000000178     731Y001            3.1.1.1. 주요국 통화의 대원화환율     D       Y
# 435  0000000178     731Y002           3.1.1.2. 주요국 통화의 대미달러환율     D       Y
# 436  0000000178     731Y003  3.1.1.3. 원화의 대미달러, 원화의 대위안/대엔 환율     D       Y
# 437  0000000177  0000000182                  3.1.2. 평균환율/기말환율  None       N
# 438  0000000182     731Y004            3.1.2.1. 주요국 통화의 대원화환율     M       Y
# 439  0000000182     731Y005           3.1.2.2. 주요국 통화의 대미달러환율     M       Y
# 440  0000000182     731Y006  3.1.2.3. 원화의 대미달러, 원화의 대위안/대엔 환율     M       Y
# 840  0000000396  0000000704               9.2.3. 북한의 시장물가와 환율  None       N
# 842  0000000704     252Y002                     9.2.3.2. 시장환율     Q       Y
#
#     ORG_NAME
# 431     None
# 432     None
# 433     None
# 434  서울외국환중개
# 435  서울외국환중개
# 436     한국은행
# 437     None
# 438     한국은행
# 439     한국은행
# 440     한국은행
# 840     None
# 842     한국은행

# %%
df_result.head(10)
# Out:
#   P_STAT_CODE   STAT_CODE                         STAT_NAME CYCLE SRCH_YN  \
# 0           *  0000000001                          1. 통화/금융  None       N
# 1  0000000001  0000000002                       1.1. 통화/유동성  None       N
# 2  0000000002  0000000003                       1.1.1. 본원통화  None       N
# 3  0000000003  0000000004                1.1.1.1. 본원통화 구성내역  None       N
# 4  0000000004     102Y004  1.1.1.1.1. 본원통화 구성내역(평잔, 계절조정계열)     M       Y
# 5  0000000004     102Y002     1.1.1.1.2. 본원통화 구성내역(평잔, 원계열)     M       Y
# 6  0000000004     102Y003  1.1.1.1.3. 본원통화 구성내역(말잔, 계절조정계열)     M       Y
# 7  0000000004     102Y001     1.1.1.1.4. 본원통화 구성내역(말잔, 원계열)     M       Y
# 8  0000000002  0000000005                   1.1.2. M1(협의통화)  None       N
# 9  0000000005  0000000006        1.1.2.1. M1(협의통화) 상품별 구성내역  None       N
#
#   ORG_NAME
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     한국은행
# 8     None
# 9     None

# %%
df_result.to_excel('result/'+service_name+'.xlsx')

# %% [markdown]
# ### 100대 통계지표

# %%
import requests
import json
import pandas as pd

api_key = 'T4GS4G5ZJSQI9HOTYV64'

service_name = 'KeyStatisticList'        # 100대 통계지표
req_type = 'json'
req_start, req_end = '1', '100'

url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/{req_start}/{req_end}'

response = requests.get(url)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")
    
jo = json.loads(response.text)
df_result = pd.json_normalize(jo[service_name]['row'])

# %%
df_result
# Out:
#    CLASS_NAME     KEYSTAT_NAME DATA_VALUE     CYCLE   UNIT_NAME
# 0        시장금리        한국은행 기준금리        3.5  20240422          %
# 1        시장금리         콜금리(익일물)      3.519  20240424          %
# 2        시장금리     KORIBOR(3개월)       3.56  20240424          %
# 3        시장금리       CD수익률(91일)       3.56  20240424          %
# 4        시장금리    통안증권수익률(364일)      3.432  20240424          %
# ..        ...              ...        ...       ...         ...
# 95     부동산 가격         주택매매가격지수       95.8    202403  2021.6=100
# 96     부동산 가격         주택전세가격지수       92.6    202403  2021.6=100
# 97     부동산 가격      지가변동률(전기대비)      0.134    202402          %
# 98        원자재  국제유가(Dubai, 현물)      86.63    202403         달러
# 99        원자재                금    2162.35    202403         달러
#
# [100 rows x 5 columns]

# %%
df_result.shape
# Out:
# (100, 5)

# %% [markdown]
# + 결과
#   - CLASS_NAME : 통계그룹명
#   - KEYSTAT_NAME : 통계명
#   - DATA_VALUE : 값
#   - CYCLE : 통계의 최근수록 시점
#   - UNIT_NAME : 단위

# %%
df_result['CLASS_NAME'].value_counts()
# Out:
# CLASS_NAME
# 시장금리          8
# 생산            7
# 투자            7
# 성장률           5
# 국제수지          5
# 고용            4
# 예금/대출금        4
# 통화량           4
# 환율            4
# 주식            4
# 소비자/생산자 물가    4
# 통관수출입         4
# 부동산 가격        3
# 대외채권/채무       3
# 인구            3
# 노동            3
# 심리지표          3
# 기업경영지표        3
# 소비            3
# GDP대비 비율      3
# 소득분배지표        2
# 가계            2
# 여수신금리         2
# 경기순환지표        2
# 소득            2
# 수출입 물가        2
# 채권            2
# 원자재           2
# Name: count, dtype: int64

# %%
df_result.to_excel('output/'+service_name+'.xlsx')

# %% [markdown]
# ### 통계조회 (모듈화)

# %%
def bok_statistic_search(statcode, freq, period_start, period_end, item, req_start, req_end):
    api_key = 'T4GS4G5ZJSQI9HOTYV64'
    service_name = 'StatisticSearch'
    req_type = 'json'
    url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/{req_start}/{req_end}/{statcode}/{freq}/{period_start}/{period_end}/{item}'
    response = requests.get(url)
    if response.status_code != 200:     # URL GET '200 정상'
        return None
    jo = json.loads(response.text)
    result = pd.json_normalize(jo[service_name]['row'])
    return result

# %%
# 통계조회: 주요국 통화의 대원화환율 - 원/미국달러(매매기준율)
df_result1 = bok_statistic_search(statcode='731Y001', freq='D', period_start='20230101', period_end='20230630', item='0000001' , req_start='1', req_end='200')
# 통계조회: 소비자물가지수
df_result2 = bok_statistic_search(statcode='901Y009', freq='M', period_start='200001', period_end='202005', item='0' , req_start='1', req_end='10000')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 6
#       4 df_result2 = bok_statistic_search(statcode='901Y009', freq='M', period_start='200001', period_end='202005', item='0' , req_start='1', req_end='10000')
#       5 # 통계조회: 에너지소바량
# ----> 6 df_result3 = bok_statistic_search(statcode='901Y072', freq='M', period_start='202401', period_end='202404', item='0' , req_start='1', req_end='10000')
#
# Cell In[21], line 10, in bok_statistic_search(statcode, freq, period_start, period_end, item, req_start, req_end)
#       8     return None
#       9 jo = json.loads(response.text)
# ---> 10 result = pd.json_normalize(jo[service_name]['row'])
#      11 return result
#
# KeyError: 'StatisticSearch'

# %%
df_result1.head(2)
# Out:
#   STAT_CODE               STAT_NAME ITEM_CODE1     ITEM_NAME1 ITEM_CODE2  \
# 0   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 1   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
#
#   ITEM_NAME2 ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME   WGT  \
# 0       None       None       None       None       None        원   None
# 1       None       None       None       None       None        원   None
#
#        TIME DATA_VALUE
# 0  20230102     1267.3
# 1  20230103     1268.9

# %%
df_result2.head(2)
# Out:
#   STAT_CODE       STAT_NAME ITEM_CODE1 ITEM_NAME1 ITEM_CODE2 ITEM_NAME2  \
# 0   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 1   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
#
#   ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME   WGT    TIME  \
# 0       None       None       None       None  2020=100  1000  200001
# 1       None       None       None       None  2020=100  1000  200002
#
#   DATA_VALUE
# 0     62.456
# 1     62.647

# %%
statcode='731Y001'
freq='D'
period_start='20240401'
period_end='20240425'
item='0000001'
req_start='1'
req_end='10000'

api_key = 'T4GS4G5ZJSQI9HOTYV64'
service_name = 'StatisticSearch'
req_type = 'json'
url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/{req_start}/{req_end}/{statcode}/{freq}/{period_start}/{period_end}/{item}'
response = requests.get(url)
jo = json.loads(response.text)
result = pd.json_normalize(jo[service_name]['row'])

# %%
result
# Out:
#    STAT_CODE               STAT_NAME ITEM_CODE1     ITEM_NAME1 ITEM_CODE2  \
# 0    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 1    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 2    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 3    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 4    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 5    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 6    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 7    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 8    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 9    731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 10   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 11   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 12   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 13   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 14   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 15   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 16   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 17   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
#
#    ITEM_NAME2 ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME   WGT  \
# 0        None       None       None       None       None        원   None
# 1        None       None       None       None       None        원   None
# 2        None       None       None       None       None        원   None
# 3        None       None       None       None       None        원   None
# 4        None       None       None       None       None        원   None
# 5        None       None       None       None       None        원   None
# 6        None       None       None       None       None        원   None
# 7        None       None       None       None       None        원   None
# 8        None       None       None       None       None        원   None
# 9        None       None       None       None       None        원   None
# 10       None       None       None       None       None        원   None
# 11       None       None       None       None       None        원   None
# 12       None       None       None       None       None        원   None
# 13       None       None       None       None       None        원   None
# 14       None       None       None       None       None        원   None
# 15       None       None       None       None       None        원   None
# 16       None       None       None       None       None        원   None
# 17       None       None       None       None       None        원   None
#
#         TIME DATA_VALUE
# 0   20240401     1347.4
# 1   20240402     1347.1
# 2   20240403       1353
# 3   20240404     1349.1
# 4   20240405     1346.8
# 5   20240408     1351.8
# 6   20240409     1353.6
# 7   20240411     1354.4
# 8   20240412     1363.7
# 9   20240415     1371.6
# 10  20240416     1383.7
# 11  20240417     1395.3
# 12  20240418     1386.3
# 13  20240419     1375.9
# 14  20240422       1385
# 15  20240423     1380.6
# 16  20240424     1377.9
# 17  20240425       1370

# %% [markdown]
# ### 통계조회: 주요국 통화의 대원화환율

# %%
import requests
import json
import pandas as pd

api_key = 'T4GS4G5ZJSQI9HOTYV64'

service_name = 'StatisticSearch'
statcode = '731Y001'
req_type = 'json'
freq, start, end = 'D', '20230101', '20230630'
# item = ''     # 지정하지 않으면 전체 대상
item = '0000001'    # 원/미국달러(매매기준율)

url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/1/10000/{statcode}/{freq}/{start}/{end}/{item}'

response = requests.get(url)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")
    
jo = json.loads(response.text)
# print(jo['RESULT']['CODE'])
df_result = pd.json_normalize(jo[service_name]['row'])

# %%
df_result.shape
# Out:
# (123, 13)

# %%
df_result.head()
# Out:
#   STAT_CODE               STAT_NAME ITEM_CODE1     ITEM_NAME1 ITEM_CODE2  \
# 0   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 1   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 2   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 3   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
# 4   731Y001  3.1.1.1. 주요국 통화의 대원화환율    0000001  원/미국달러(매매기준율)       None
#
#   ITEM_NAME2 ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME      TIME  \
# 0       None       None       None       None       None        원   20230102
# 1       None       None       None       None       None        원   20230103
# 2       None       None       None       None       None        원   20230104
# 3       None       None       None       None       None        원   20230105
# 4       None       None       None       None       None        원   20230106
#
#   DATA_VALUE
# 0     1267.3
# 1     1268.9
# 2     1272.1
# 3     1274.7
# 4     1270.3

# %%
df_result.to_excel('result/'+service_name+'_'+statcode+'.xlsx')

# %% [markdown]
# ### 통계조회: 소비자물가지수

# %%
import requests
import json
import pandas as pd

api_key = 'T4GS4G5ZJSQI9HOTYV64'

service_name = 'StatisticSearch'
statcode = '901Y009'        # 소비자물가지수
req_type = 'json'
freq, start, end, item = 'M', '200001', '202005', '0'

url = f'http://ecos.bok.or.kr/api/{service_name}/{api_key}/{req_type}/kr/1/10000/{statcode}/{freq}/{start}/{end}/{item}'

response = requests.get(url)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")
    
jo = json.loads(response.text)
df_result = pd.json_normalize(jo[service_name]['row'])

# %%
df_result.shape
# Out:
# (245, 13)

# %%
df_result
# Out:
#     STAT_CODE       STAT_NAME ITEM_CODE1 ITEM_NAME1 ITEM_CODE2 ITEM_NAME2  \
# 0     901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 1     901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 2     901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 3     901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 4     901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# ..        ...             ...        ...        ...        ...        ...
# 240   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 241   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 242   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 243   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
# 244   901Y009  4.2.1. 소비자물가지수          0        총지수       None       None
#
#     ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4 UNIT_NAME    TIME DATA_VALUE
# 0         None       None       None       None  2020=100  200001     62.456
# 1         None       None       None       None  2020=100  200002     62.647
# 2         None       None       None       None  2020=100  200003     62.962
# 3         None       None       None       None  2020=100  200004     62.709
# 4         None       None       None       None  2020=100  200005     62.393
# ..         ...        ...        ...        ...       ...     ...        ...
# 240       None       None       None       None  2020=100  202001     100.09
# 241       None       None       None       None  2020=100  202002     100.16
# 242       None       None       None       None  2020=100  202003      99.94
# 243       None       None       None       None  2020=100  202004       99.5
# 244       None       None       None       None  2020=100  202005      99.44
#
# [245 rows x 13 columns]

# %%
df_result.to_excel('result/'+service_name+'_'+statcode+'.xlsx')
