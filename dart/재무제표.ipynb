# %% [markdown]
# ### [DART] 단일회사 전체 재무제표
# * https://opendart.fss.or.kr/guide/detail.do?apiGrpCd=DS003&apiId=2019020

# %%
import requests

# 상장기업 재무정보 - 단일회사 전체 재무제표
url = 'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json'
api_key = 'f2e08d4ed3de0ba3d5cbf59c04c223e02b1751a2'
corp_code = '00126380'  # 삼성전자
fs_div = 'OFS'      # CFS:연결재무제표, OFS:재무제표
fyear = '2022'        # 사업연도
rpt_code = '11011'  # 사업보고서

params = {
    'corp_code': corp_code,
    'bsns_year': fyear,         
    'reprt_code': rpt_code,        
    'fs_div': fs_div,           
    'crtfc_key': api_key,
}

response = requests.get(url, params=params)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")

# %% [markdown]
# - BS : 재무상태표
# - IS : 손익계산서
# - CIS : 포괄손익계산서
# - CF : 현금흐름표
# - SCE : 자본변동표

# %%
# 데이터프레임 형태로 변환, 데이터 타입 변환
import pandas as pd
df_fi = pd.json_normalize(response.json()['list'])
df_fi['thstrm_amount'].fillna(0)
df_fi['frmtrm_amount'].fillna(0)
df_fi['bfefrmtrm_amount'].fillna(0)
df_fi['thstrm_add_amount'].fillna(0)
df_fi = df_fi.astype({'ord' : 'int'})

# %%
df_fi.columns
# Out:
# Index(['rcept_no', 'reprt_code', 'bsns_year', 'corp_code', 'sj_div', 'sj_nm',
#        'account_id', 'account_nm', 'account_detail', 'thstrm_nm',
#        'thstrm_amount', 'frmtrm_nm', 'frmtrm_amount', 'bfefrmtrm_nm',
#        'bfefrmtrm_amount', 'ord', 'currency', 'thstrm_add_amount'],
#       dtype='object')

# %%
df_fi
# Out:
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20230307000542      11011      2022  00126380     BS  재무상태표
# 1    20230307000542      11011      2022  00126380     BS  재무상태표
# 2    20230307000542      11011      2022  00126380     BS  재무상태표
# 3    20230307000542      11011      2022  00126380     BS  재무상태표
# 4    20230307000542      11011      2022  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 109  20230307000542      11011      2022  00126380    SCE  자본변동표
# 110  20230307000542      11011      2022  00126380    SCE  자본변동표
# 111  20230307000542      11011      2022  00126380    SCE  자본변동표
# 112  20230307000542      11011      2022  00126380    SCE  자본변동표
# 113  20230307000542      11011      2022  00126380    SCE  자본변동표
#
#                                             account_id account_nm  \
# 0                              ifrs-full_CurrentAssets       유동자산
# 1                     ifrs-full_CashAndCashEquivalents   현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...     단기금융상품
# 3                        dart_ShortTermTradeReceivable       매출채권
# 4                       dart_ShortTermOtherReceivables        미수금
# ..                                                 ...        ...
# 109                                   ifrs-full_Equity       기말자본
# 110                                   ifrs-full_Equity       기말자본
# 111                                   ifrs-full_Equity       기말자본
# 112                                   ifrs-full_Equity       기말자본
# 113                                   ifrs-full_Equity       기말자본
#
#                  account_detail thstrm_nm    thstrm_amount frmtrm_nm  \
# 0                             -    제 54 기   59062658000000    제 53 기
# 1                             -    제 54 기    3921593000000    제 53 기
# 2                             -    제 54 기        137000000    제 53 기
# 3                             -    제 54 기   20503223000000    제 53 기
# 4                             -    제 54 기    2925006000000    제 53 기
# ..                          ...       ...              ...       ...
# 109             별도재무제표 [member]    제 54 기  209416191000000    제 53 기
# 110  자본 [member]|이익잉여금 [member]    제 54 기  204388016000000    제 53 기
# 111         자본 [member]|주식발행초과금    제 54 기    4403893000000    제 53 기
# 112    자본 [member]|자본금 [member]    제 54 기     897514000000    제 53 기
# 113          자본 [member]|기타자본항목    제 54 기    -273232000000    제 53 기
#
#        frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount  ord currency  \
# 0     73553416000000       제 52 기   73798549000000    1      KRW
# 1      3918872000000       제 52 기     989045000000    2      KRW
# 2     15000576000000       제 52 기   29101284000000    3      KRW
# 3     33088247000000       제 52 기   24736740000000    4      KRW
# 4      1832488000000       제 52 기    1898583000000    5      KRW
# ..               ...          ...              ...  ...      ...
# 109  193193732000000       제 52 기  183316724000000    6      KRW
# 110  188774335000000       제 52 기  178284102000000    6      KRW
# 111    4403893000000       제 52 기    4403893000000    6      KRW
# 112     897514000000       제 52 기     897514000000    6      KRW
# 113    -882010000000       제 52 기    -268785000000    6      KRW
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 109               NaN
# 110               NaN
# 111               NaN
# 112               NaN
# 113               NaN
#
# [114 rows x 18 columns]

# %% [markdown]
# #### 포괄손익계산서

# %%
sj_div = "CIS"  # 포괄손익계산서
df_cis = df_fi.query('sj_div == @sj_div').sort_values('ord')

# %% [markdown]
# > 항목: XBRL 표준계정ID
# - 매출액 ifrs-full_Revenue
# - 영업이익 dart_OperatingIncomeLoss
# - 비영업이익
# - 연구개발비
# - 광고선전비
# - 이자비용
# - EBIT

# %%
df_cis.shape
# Out:
# (7, 18)

# %%
acct_id = ['ifrs-full_Revenue', 'dart_OperatingIncomeLoss']
df_cis.query('account_id in @acct_id')[['account_id', 'account_nm', 'thstrm_amount', 'currency']]          # 당기금액
# Out:
# Empty DataFrame
# Columns: [account_id, account_nm, thstrm_amount, currency]
# Index: []

# %% [markdown]
# #### 재무상태표

# %%
sj_div = "BS"  # 재무상태표
df_bs = df_fi.query('sj_div == @sj_div').sort_values('ord')

# %% [markdown]
# > 항목 XBRL 표준계정ID
# - 총자산 ifrs-full_Assets
# - 총부채 ifrs-full_Liabilities

# %%
acct_id = ['ifrs-full_Assets',
           'ifrs-full_Liabilities']
df_bs.query('account_id in @acct_id')[['account_id', 'account_nm', 'thstrm_amount', 'currency']]          # 당기금액
# df_bs[df_bs['account_nm'].str.contains('자산')]
# Out:
#                account_id account_nm    thstrm_amount currency
# 17       ifrs-full_Assets       자산총계  260083750000000      KRW
# 35  ifrs-full_Liabilities       부채총계   50667559000000      KRW

# %%
df_bs.shape
# Out:
# (44, 18)

# %%
df_bs
# Out:
#           rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0   20230307000542      11011      2022  00126380     BS  재무상태표
# 1   20230307000542      11011      2022  00126380     BS  재무상태표
# 2   20230307000542      11011      2022  00126380     BS  재무상태표
# 3   20230307000542      11011      2022  00126380     BS  재무상태표
# 4   20230307000542      11011      2022  00126380     BS  재무상태표
# 5   20230307000542      11011      2022  00126380     BS  재무상태표
# 6   20230307000542      11011      2022  00126380     BS  재무상태표
# 7   20230307000542      11011      2022  00126380     BS  재무상태표
# 8   20230307000542      11011      2022  00126380     BS  재무상태표
# 9   20230307000542      11011      2022  00126380     BS  재무상태표
# 10  20230307000542      11011      2022  00126380     BS  재무상태표
# 11  20230307000542      11011      2022  00126380     BS  재무상태표
# 12  20230307000542      11011      2022  00126380     BS  재무상태표
# 13  20230307000542      11011      2022  00126380     BS  재무상태표
# 14  20230307000542      11011      2022  00126380     BS  재무상태표
# 15  20230307000542      11011      2022  00126380     BS  재무상태표
# 16  20230307000542      11011      2022  00126380     BS  재무상태표
# 17  20230307000542      11011      2022  00126380     BS  재무상태표
# 18  20230307000542      11011      2022  00126380     BS  재무상태표
# 19  20230307000542      11011      2022  00126380     BS  재무상태표
# 20  20230307000542      11011      2022  00126380     BS  재무상태표
# 21  20230307000542      11011      2022  00126380     BS  재무상태표
# 22  20230307000542      11011      2022  00126380     BS  재무상태표
# 23  20230307000542      11011      2022  00126380     BS  재무상태표
# 24  20230307000542      11011      2022  00126380     BS  재무상태표
# 25  20230307000542      11011      2022  00126380     BS  재무상태표
# 26  20230307000542      11011      2022  00126380     BS  재무상태표
# 27  20230307000542      11011      2022  00126380     BS  재무상태표
# 28  20230307000542      11011      2022  00126380     BS  재무상태표
# 29  20230307000542      11011      2022  00126380     BS  재무상태표
# 30  20230307000542      11011      2022  00126380     BS  재무상태표
# 31  20230307000542      11011      2022  00126380     BS  재무상태표
# 32  20230307000542      11011      2022  00126380     BS  재무상태표
# 33  20230307000542      11011      2022  00126380     BS  재무상태표
# 34  20230307000542      11011      2022  00126380     BS  재무상태표
# 35  20230307000542      11011      2022  00126380     BS  재무상태표
# 36  20230307000542      11011      2022  00126380     BS  재무상태표
# 37  20230307000542      11011      2022  00126380     BS  재무상태표
# 38  20230307000542      11011      2022  00126380     BS  재무상태표
# 39  20230307000542      11011      2022  00126380     BS  재무상태표
# 40  20230307000542      11011      2022  00126380     BS  재무상태표
# 41  20230307000542      11011      2022  00126380     BS  재무상태표
# 42  20230307000542      11011      2022  00126380     BS  재무상태표
# 43  20230307000542      11011      2022  00126380     BS  재무상태표
#
#                                            account_id            account_nm  \
# 0                             ifrs-full_CurrentAssets                  유동자산
# 1                    ifrs-full_CashAndCashEquivalents              현금및현금성자산
# 2   dart_ShortTermDepositsNotClassifiedAsCashEquiv...                단기금융상품
# 3                       dart_ShortTermTradeReceivable                  매출채권
# 4                      dart_ShortTermOtherReceivables                   미수금
# 5                                        -표준계정코드 미사용-                  선급비용
# 6                               ifrs-full_Inventories                  재고자산
# 7                             dart_OtherCurrentAssets                기타유동자산
# 8                          ifrs-full_NoncurrentAssets                 비유동자산
# 9                                        -표준계정코드 미사용-       기타포괄손익-공정가치금융자산
# 10                                       -표준계정코드 미사용-         당기손익-공정가치금융자산
# 11  ifrs-full_InvestmentsInSubsidiariesJointVentur...  종속기업, 관계기업 및 공동기업 투자
# 12                ifrs-full_PropertyPlantAndEquipment                  유형자산
# 13        ifrs-full_IntangibleAssetsOtherThanGoodwill                  무형자산
# 14                 dart_DepositsForSeveranceInsurance               순확정급여자산
# 15                        ifrs-full_DeferredTaxAssets               이연법인세자산
# 16                         dart_OtherNonCurrentAssets               기타비유동자산
# 17                                   ifrs-full_Assets                  자산총계
# 18                       ifrs-full_CurrentLiabilities                  유동부채
# 19                                       -표준계정코드 미사용-                  매입채무
# 20                      ifrs-full_ShorttermBorrowings                 단기차입금
# 21                                       -표준계정코드 미사용-                  미지급금
# 22                                       -표준계정코드 미사용-                   선수금
# 23                                       -표준계정코드 미사용-                   예수금
# 24                                       -표준계정코드 미사용-                 미지급비용
# 25                    ifrs-full_CurrentTaxLiabilities               당기법인세부채
# 26                                       -표준계정코드 미사용-               유동성장기부채
# 27                        ifrs-full_CurrentProvisions                  충당부채
# 28                       dart_OtherCurrentLiabilities                기타유동부채
# 29                    ifrs-full_NoncurrentLiabilities                 비유동부채
# 30                                   dart_BondsIssued                    사채
# 31                       dart_LongTermBorrowingsGross                 장기차입금
# 32                    dart_LongTermOtherPayablesGross                장기미지급금
# 33                     ifrs-full_NoncurrentProvisions                장기충당부채
# 34                    dart_OtherNonCurrentLiabilities               기타비유동부채
# 35                              ifrs-full_Liabilities                  부채총계
# 36                            ifrs-full_IssuedCapital                   자본금
# 37                 dart_IssuedCapitalOfPreferredStock                우선주자본금
# 38                    dart_IssuedCapitalOfCommonStock                보통주자본금
# 39                             ifrs-full_SharePremium               주식발행초과금
# 40                         ifrs-full_RetainedEarnings            이익잉여금(결손금)
# 41             dart_ElementsOfOtherStockholdersEquity                기타자본항목
# 42                                   ifrs-full_Equity                  자본총계
# 43                     ifrs-full_EquityAndLiabilities               부채와자본총계
#
#    account_detail thstrm_nm    thstrm_amount frmtrm_nm    frmtrm_amount  \
# 0               -    제 54 기   59062658000000    제 53 기   73553416000000
# 1               -    제 54 기    3921593000000    제 53 기    3918872000000
# 2               -    제 54 기        137000000    제 53 기   15000576000000
# 3               -    제 54 기   20503223000000    제 53 기   33088247000000
# 4               -    제 54 기    2925006000000    제 53 기    1832488000000
# 5               -    제 54 기    1047900000000    제 53 기     817689000000
# 6               -    제 54 기   27990007000000    제 53 기   15973053000000
# 7               -    제 54 기    2674792000000    제 53 기    2922491000000
# 8               -    제 54 기  201021092000000    제 53 기  177558768000000
# 9               -    제 54 기    1364325000000    제 53 기    1662532000000
# 10              -    제 54 기        283000000    제 53 기       2135000000
# 11              -    제 54 기   57397249000000    제 53 기   56225599000000
# 12              -    제 54 기  123266986000000    제 53 기  103667025000000
# 13              -    제 54 기    8561424000000    제 53 기    8657456000000
# 14              -    제 54 기    4410223000000    제 53 기    2324291000000
# 15              -    제 54 기    2142512000000    제 53 기    1211100000000
# 16              -    제 54 기    3878090000000    제 53 기    3808630000000
# 17              -    제 54 기  260083750000000    제 53 기  251112184000000
# 18              -    제 54 기   46086047000000    제 53 기   53067303000000
# 19              -    제 54 기    8729315000000    제 53 기   11557441000000
# 20              -    제 54 기    2381512000000    제 53 기    9204268000000
# 21              -    제 54 기   18554543000000    제 53 기   13206753000000
# 22              -    제 54 기     320689000000    제 53 기     474731000000
# 23              -    제 54 기     523354000000    제 53 기     624585000000
# 24              -    제 54 기    8359296000000    제 53 기    8275410000000
# 25              -    제 54 기    2533481000000    제 53 기    5599896000000
# 26              -    제 54 기     135753000000    제 53 기     139328000000
# 27              -    제 54 기    4059491000000    제 53 기    3643853000000
# 28              -    제 54 기     488613000000    제 53 기     341038000000
# 29              -    제 54 기    4581512000000    제 53 기    4851149000000
# 30              -    제 54 기      24912000000    제 53 기      29048000000
# 31              -    제 54 기     654979000000    제 53 기     431915000000
# 32              -    제 54 기    2439232000000    제 53 기    2653715000000
# 33              -    제 54 기    1423165000000    제 53 기    1659774000000
# 34              -    제 54 기      39224000000    제 53 기      76697000000
# 35              -    제 54 기   50667559000000    제 53 기   57918452000000
# 36              -    제 54 기     897514000000    제 53 기     897514000000
# 37              -    제 54 기     119467000000    제 53 기     119467000000
# 38              -    제 54 기     778047000000    제 53 기     778047000000
# 39              -    제 54 기    4403893000000    제 53 기    4403893000000
# 40              -    제 54 기  204388016000000    제 53 기  188774335000000
# 41              -    제 54 기    -273232000000    제 53 기    -882010000000
# 42              -    제 54 기  209416191000000    제 53 기  193193732000000
# 43              -    제 54 기  260083750000000    제 53 기  251112184000000
#
#    bfefrmtrm_nm bfefrmtrm_amount  ord currency thstrm_add_amount
# 0        제 52 기   73798549000000    1      KRW               NaN
# 1        제 52 기     989045000000    2      KRW               NaN
# 2        제 52 기   29101284000000    3      KRW               NaN
# 3        제 52 기   24736740000000    4      KRW               NaN
# 4        제 52 기    1898583000000    5      KRW               NaN
# 5        제 52 기     890680000000    6      KRW               NaN
# 6        제 52 기   13831372000000    7      KRW               NaN
# 7        제 52 기    2350845000000    8      KRW               NaN
# 8        제 52 기  155865878000000    9      KRW               NaN
# 9        제 52 기    1539659000000   10      KRW               NaN
# 10       제 52 기       3107000000   11      KRW               NaN
# 11       제 52 기   56587548000000   12      KRW               NaN
# 12       제 52 기   86166924000000   13      KRW               NaN
# 13       제 52 기    7002648000000   14      KRW               NaN
# 14       제 52 기    1162456000000   15      KRW               NaN
# 15       제 52 기     992385000000   16      KRW               NaN
# 16       제 52 기    2411151000000   17      KRW               NaN
# 17       제 52 기  229664427000000   18      KRW               NaN
# 18       제 52 기   44412904000000   20      KRW               NaN
# 19       제 52 기    6599025000000   21      KRW               NaN
# 20       제 52 기   12520367000000   22      KRW               NaN
# 21       제 52 기    9829541000000   23      KRW               NaN
# 22       제 52 기     424368000000   24      KRW               NaN
# 23       제 52 기     432714000000   25      KRW               NaN
# 24       제 52 기    7927017000000   26      KRW               NaN
# 25       제 52 기    3556146000000   27      KRW               NaN
# 26       제 52 기      87571000000   28      KRW               NaN
# 27       제 52 기    2932468000000   29      KRW               NaN
# 28       제 52 기     103687000000   30      KRW               NaN
# 29       제 52 기    1934799000000   31      KRW               NaN
# 30       제 52 기      31909000000   32      KRW               NaN
# 31       제 52 기     150397000000   33      KRW               NaN
# 32       제 52 기    1247752000000   34      KRW               NaN
# 33       제 52 기     503035000000   35      KRW               NaN
# 34       제 52 기       1706000000   36      KRW               NaN
# 35       제 52 기   46347703000000   37      KRW               NaN
# 36       제 52 기     897514000000   39      KRW               NaN
# 37       제 52 기     119467000000   40      KRW               NaN
# 38       제 52 기     778047000000   41      KRW               NaN
# 39       제 52 기    4403893000000   42      KRW               NaN
# 40       제 52 기  178284102000000   43      KRW               NaN
# 41       제 52 기    -268785000000   44      KRW               NaN
# 42       제 52 기  183316724000000   45      KRW               NaN
# 43       제 52 기  229664427000000   46      KRW               NaN

# %% [markdown]
# #### 현금흐름표

# %%
sj_div = "CF"  # 현금흐름표
df_cf = df_fi.query('sj_div == @sj_div').sort_values('ord')

# %% [markdown]
# > 항목 XBRL 표준계정ID
# - 영업활동현금흐름 ifrs-full_CashFlowsFromUsedInOperatingActivities
# - 영업으로부터 창출된 현금흐름 dart_NetCashflowsFromUsedInOperations

# %%
acct_id = ['ifrs-full_CashFlowsFromUsedInOperatingActivities',
           'dart_NetCashflowsFromUsedInOperations']
df_cf.query('account_id in @acct_id')[['account_id', 'account_nm', 'thstrm_amount', 'currency']]          # 당기금액
# Out:
#                                           account_id account_nm  \
# 66  ifrs-full_CashFlowsFromUsedInOperatingActivities  영업활동 현금흐름
#
#      thstrm_amount currency
# 66  44788749000000      KRW
