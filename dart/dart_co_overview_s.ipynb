# %% [markdown]
# ## 기업 개황(Overview) : 단일 회사
# + 작성: 임경호

# %%
import requests

url = 'https://opendart.fss.or.kr/api/company.json'
api_key = 'f2e08d4ed3de0ba3d5cbf59c04c223e02b1751a2'
corp_code = '00787376'
params = {
    'corp_code': corp_code,
    'crtfc_key': api_key,
}

response = requests.get(url, params=params)
if response.status_code != 200:     # URL GET '200 정상'
    print("URL GET Error")

# %%
response.json()
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00787376',
#  'corp_name': '대성에너지(주)',
#  'corp_name_eng': 'DAESUNG ENERGY CO.,LTD',
#  'stock_name': '대성에너지',
#  'stock_code': '117580',
#  'ceo_nm': '대표이사 김영훈 대표이사 윤홍식',
#  'corp_cls': 'Y',
#  'jurir_no': '1701110387416',
#  'bizr_no': '5048183652',
#  'adres': '대구광역시 중구 명덕로 85 (남산동)',
#  'hm_url': 'www.daesungenergy.com',
#  'ir_url': '',
#  'phn_no': '053-606-1000',
#  'fax_no': '053)606-1004',
#  'induty_code': '35200',
#  'est_dt': '20091001',
#  'acc_mt': '12'}

# %%
# 데이터프레임 형태로 변환
import pandas as pd
corp_overview = pd.json_normalize(response.json())

# %%
corp_overview
# Out:
#   status message corp_code corp_name           corp_name_eng stock_name  \
# 0    000      정상  00787376  대성에너지(주)  DAESUNG ENERGY CO.,LTD      대성에너지
#
#   stock_code             ceo_nm corp_cls       jurir_no     bizr_no  \
# 0     117580  대표이사 김영훈 대표이사 윤홍식        Y  1701110387416  5048183652
#
#                    adres                 hm_url ir_url        phn_no  \
# 0  대구광역시 중구 명덕로 85 (남산동)  www.daesungenergy.com         053-606-1000
#
#          fax_no induty_code    est_dt acc_mt
# 0  053)606-1004       35200  20091001     12

# %%
corp_overview.transpose()
# Out:
#                                     0
# status                            000
# message                            정상
# corp_code                    00787376
# corp_name                    대성에너지(주)
# corp_name_eng  DAESUNG ENERGY CO.,LTD
# stock_name                      대성에너지
# stock_code                     117580
# ceo_nm              대표이사 김영훈 대표이사 윤홍식
# corp_cls                            Y
# jurir_no                1701110387416
# bizr_no                    5048183652
# adres           대구광역시 중구 명덕로 85 (남산동)
# hm_url          www.daesungenergy.com
# ir_url
# phn_no                   053-606-1000
# fax_no                   053)606-1004
# induty_code                     35200
# est_dt                       20091001
# acc_mt                             12
